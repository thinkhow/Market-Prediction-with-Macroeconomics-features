# %% [markdown]
# https://medium.com/analytics-vidhya/predicting-stock-prices-using-facebooks-prophet-model-b1716c733ea6#:~:text=Prophet%20is%20a%20procedure%20for,daily%20seasonality%2C%20plus%20holiday%20effects.&text=with%2C%20g(t)%20representing,linear%20model%20for%20trend%20forecasting.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
df = pd.read_csv("df4.csv", parse_dates=['Date'])
# df.head()

# %%
df = df[["Date","Close"]] 
# Rename the features: These names are required for the model fitting
df = df.rename(columns = {"Date":"ds","Close":"y"}) 
# df.head()

# %%
from datetime import datetime
cutoff = datetime(2020,1,1)
df_train = df.loc[df.ds < cutoff,].copy()
df_test = df.drop(df_train.index).copy()
df_test.tail(50)
# Out:
#              ds        y
# 4470 2020-11-17  3609.53
# 4471 2020-11-18  3567.79
# 4472 2020-11-19  3581.87
# 4473 2020-11-20  3557.54
# 4474 2020-11-23  3577.59
# 4475 2020-11-24  3635.41
# 4476 2020-11-25  3629.65
# 4477 2020-11-27  3638.35
# 4478 2020-11-30  3621.63
# 4479 2020-12-01  3662.45
# 4480 2020-12-02  3669.01
# 4481 2020-12-03  3666.72
# 4482 2020-12-04  3699.12
# 4483 2020-12-07  3691.96
# 4484 2020-12-08  3702.25
# 4485 2020-12-09  3672.82
# 4486 2020-12-10  3668.10
# 4487 2020-12-11  3663.46
# 4488 2020-12-14  3647.49
# 4489 2020-12-15  3694.62
# 4490 2020-12-16  3701.17
# 4491 2020-12-17  3722.48
# 4492 2020-12-18  3709.41
# 4493 2020-12-21  3694.92
# 4494 2020-12-22  3687.26
# 4495 2020-12-23  3690.01
# 4496 2020-12-24  3703.06
# 4497 2020-12-28  3735.36
# 4498 2020-12-29  3727.04
# 4499 2020-12-30  3732.04
# 4500 2020-12-31  3756.07
# 4501 2021-01-04  3700.65
# 4502 2021-01-05  3726.86
# 4503 2021-01-06  3748.14
# 4504 2021-01-07  3803.79
# 4505 2021-01-08  3824.68
# 4506 2021-01-11  3799.61
# 4507 2021-01-12  3801.19
# 4508 2021-01-13  3809.84
# 4509 2021-01-14  3795.54
# 4510 2021-01-15  3768.25
# 4511 2021-01-19  3798.91
# 4512 2021-01-20  3851.85
# 4513 2021-01-21  3853.07
# 4514 2021-01-22  3841.47
# 4515 2021-01-25  3855.36
# 4516 2021-01-26  3849.62
# 4517 2021-01-27  3750.77
# 4518 2021-01-28  3787.38
# 4519 2021-01-29  3714.24

# %%
from fbprophet import Prophet
fbp = Prophet(daily_seasonality = True) 
fbp.fit(df_train)
# We need to specify the number of days in future
# We'll be predicting the full 2021 stock prices
fut = fbp.make_future_dataframe(periods=366) 
forecast = fbp.predict(fut)

# %%
fc_train = forecast.loc[forecast.ds < cutoff,].copy()
fc_test = forecast.drop(fc_train.index).copy()

# %%
import trading_calendars as tc
import pandas as pd
import pytz

xnys = tc.get_calendar('XNYS')
trading_days = [x for x in fc_test.ds if xnys.is_session(x)]
# Out:
# <ipython-input-19-ca852d8ba927>:6: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
#   trading_days = [x for x in fc_test.ds if xnys.is_session(x)]

# %%
idx = [i for i in fc_test.index if fc_test.ds[i] in trading_days]
fc_test = fc_test.loc[idx, ]
fc_test
# Out:
#              ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 4251 2020-01-02  3139.687514  3026.529723  3168.618974  3139.687514
# 4252 2020-01-03  3140.417328  3026.110532  3172.838539  3140.417328
# 4255 2020-01-06  3142.606772  3028.203076  3168.186796  3142.606772
# 4256 2020-01-07  3143.336586  3025.761938  3179.128869  3143.336586
# 4257 2020-01-08  3144.066401  3025.584418  3175.124537  3144.066401
# ...         ...          ...          ...          ...          ...
# 4608 2020-12-24  3400.231301  3147.219551  3566.627004  3203.998963
# 4612 2020-12-28  3403.150560  3150.575810  3580.988377  3205.834888
# 4613 2020-12-29  3403.880374  3144.215033  3560.608868  3205.470417
# 4614 2020-12-30  3404.610189  3153.054721  3573.891751  3205.105946
# 4615 2020-12-31  3405.340003  3127.308482  3566.156366  3204.655874
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 4251  3139.687514      -44.000409            -44.000409            -44.000409
# 4252  3140.417328      -43.764092            -43.764092            -43.764092
# 4255  3142.606772      -44.443363            -44.443363            -44.443363
# 4256  3143.336586      -42.334985            -42.334985            -42.334985
# 4257  3144.066401      -43.496810            -43.496810            -43.496810
# ...           ...             ...                   ...                   ...
# 4608  3586.847517      -44.633647            -44.633647            -44.633647
# 4612  3592.035487      -45.966515            -45.966515            -45.966515
# 4613  3593.302428      -43.869762            -43.869762            -43.869762
# 4614  3594.569369      -44.940189            -44.940189            -44.940189
# 4615  3596.964498      -44.265592            -44.265592            -44.265592
#
#           daily  ...    weekly  weekly_lower  weekly_upper    yearly  \
# 4251 -45.901201  ... -2.096069     -2.096069     -2.096069  3.996862
# 4252 -45.901201  ... -2.083126     -2.083126     -2.083126  4.220236
# 4255 -45.901201  ... -3.349597     -3.349597     -3.349597  4.807436
# 4256 -45.901201  ... -1.362075     -1.362075     -1.362075  4.928291
# 4257 -45.901201  ... -2.584432     -2.584432     -2.584432  4.988824
# ...         ...  ...       ...           ...           ...       ...
# 4608 -45.901201  ... -2.096069     -2.096069     -2.096069  3.363624
# 4612 -45.901201  ... -3.349597     -3.349597     -3.349597  3.284284
# 4613 -45.901201  ... -1.362075     -1.362075     -1.362075  3.393515
# 4614 -45.901201  ... -2.584432     -2.584432     -2.584432  3.545445
# 4615 -45.901201  ... -2.096069     -2.096069     -2.096069  3.731678
#
#       yearly_lower  yearly_upper  multiplicative_terms  \
# 4251      3.996862      3.996862                   0.0
# 4252      4.220236      4.220236                   0.0
# 4255      4.807436      4.807436                   0.0
# 4256      4.928291      4.928291                   0.0
# 4257      4.988824      4.988824                   0.0
# ...            ...           ...                   ...
# 4608      3.363624      3.363624                   0.0
# 4612      3.284284      3.284284                   0.0
# 4613      3.393515      3.393515                   0.0
# 4614      3.545445      3.545445                   0.0
# 4615      3.731678      3.731678                   0.0
#
#       multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 4251                         0.0                         0.0  3095.687105
# 4252                         0.0                         0.0  3096.653236
# 4255                         0.0                         0.0  3098.163409
# 4256                         0.0                         0.0  3101.001601
# 4257                         0.0                         0.0  3100.569591
# ...                          ...                         ...          ...
# 4608                         0.0                         0.0  3355.597655
# 4612                         0.0                         0.0  3357.184044
# 4613                         0.0                         0.0  3360.010612
# 4614                         0.0                         0.0  3359.670000
# 4615                         0.0                         0.0  3361.074411
#
# [253 rows x 22 columns]

# %%
from sklearn.metrics import mean_squared_error as MSE
mse_train = MSE(fc_train.yhat,df_train.y)
mse_test = MSE(fc_test.yhat, df_test.y[:len(trading_days)])
print(mse_train, mse_test)
# Out:
# 3448.5219799368365 77409.84133925167

# %%
df_test.y[:len(trading_days)]
# Out:
# 4250    3257.85
# 4251    3234.85
# 4252    3246.28
# 4253    3237.18
# 4254    3253.05
#          ...
# 4498    3727.04
# 4499    3732.04
# 4500    3756.07
# 4501    3700.65
# 4502    3726.86
# Name: y, Length: 253, dtype: float64

# %%
fc_test[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]
# Out:
#              ds         yhat   yhat_lower   yhat_upper
# 4251 2020-01-02  3095.687105  3020.744261  3173.770740
# 4252 2020-01-03  3096.653236  3022.347402  3170.888954
# 4255 2020-01-06  3098.163409  3020.315321  3173.531656
# 4256 2020-01-07  3101.001601  3025.582968  3170.545065
# 4257 2020-01-08  3100.569591  3027.327177  3181.404636
# ...         ...          ...          ...          ...
# 4608 2020-12-24  3355.597655  3156.695881  3558.977176
# 4612 2020-12-28  3357.184044  3152.580550  3574.468979
# 4613 2020-12-29  3360.010612  3178.554206  3577.392964
# 4614 2020-12-30  3359.670000  3163.058782  3587.462397
# 4615 2020-12-31  3361.074411  3159.444621  3577.407462
#
# [253 rows x 4 columns]

# %%
from fbprophet.plot import plot
# A better plot than the simple matplotlib
plot(fbp, forecast)
