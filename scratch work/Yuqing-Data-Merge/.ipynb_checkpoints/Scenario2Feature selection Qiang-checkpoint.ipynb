# %% [markdown]
# # Gradient descent algorithm for Scenario 2
#
#
# In this part, we implement an gradient descent algorithm to optimization the objective loss function in Scenario 2:
#
#
# $$\min F := \min \frac{1}{2(n-i)} \sum_{i=1000}^n (fbpredic(i) + a*tby(i) +b*ffr(i) + c*fta(i) - asp(i))^2$$
#
# Gradient descent:
#
# $$ \beta_k = \beta_{k-1} + \delta* \nabla F, $$
# where $\delta$ control how far does each iteration go.
#
#
# ### Detailed plan
#
# First, split the data as train and test with 80% and 20% respectively. For the training part, we need prophet() predicted price, there are a couple of issues. One is prophet() can not predict too far in the future. The other is we can not call prophet() too many times, this takes a lot of time. So we will use a sliding window strategy:
#
# 1, Split the train data as train_1 and train_2, where train_1 is used as a sliding window to fit prophet(), and give predictions in train_2. Train_2 is used train the model we proposed above.
#
# 2, After we got full size (size of train_2) predictions from prophet(), then we use gradient descent to fit the above model, extracting the coefficients of features to make predicution in the testing data.

# %%
import pandas as pd
import numpy as np

## For plotting
import matplotlib.pyplot as plt
from matplotlib import style
import datetime as dt
import seaborn as sns
sns.set_style("whitegrid")

# %%
path = '/Users/yuqingdai/Documents/GitHub/Stock-Erdos/scratch work/Yuqing-Data-Merge/Data/dt'

# %%
df= pd.read_csv(path+'/dff1.csv')
df = df.rename(columns = {"Date":"ds","Close":"y"}) 
df = df[['ds', 'y', 'fbsp','diff', 'tby', 'ffr', 'fta', 'eps', 'div', 'per', 'une', 'rus',
       'wti', 'ppi', 'rfs', 'vix']]
df
# Out:
#               ds        y         fbsp        diff   tby   ffr        fta  \
# 0     2010-01-25  1096.78  1124.898600  -28.118600  3.66  0.11  2252213.0
# 1     2010-01-26  1092.17  1124.899197  -32.729197  3.65  0.11  2252213.0
# 2     2010-01-27  1097.50  1128.493288  -30.993288  3.66  0.11  2247065.0
# 3     2010-01-28  1084.53  1129.180079  -44.650079  3.68  0.11  2247065.0
# 4     2010-01-29  1073.87  1130.230192  -56.360192  3.63  0.11  2247065.0
# ...          ...      ...          ...         ...   ...   ...        ...
# 2515  2020-02-24  3225.89  3085.074930  140.815070  1.38  1.58  4171570.0
# 2516  2020-02-25  3128.21  3085.493162   42.716838  1.33  1.58  4171570.0
# 2517  2020-02-26  3116.39  3086.398961   29.991039  1.33  1.58  4158637.0
# 2518  2020-02-27  2978.76  3085.948568 -107.188568  1.30  1.58  4158637.0
# 2519  2020-02-28  2954.22  3089.102864 -134.882864  1.13  1.58  4158637.0
#
#          eps   div      per  une          rus    wti    ppi       rfs    vix
# 0      62.52  2.02  17.6247  9.8   618.109985  74.90  181.9  345959.0  24.35
# 1      62.52  2.02  17.6247  9.8   612.159973  74.67  181.9  345959.0  24.50
# 2      62.52  2.02  17.6247  9.8   618.380005  73.64  181.9  345959.0  23.70
# 3      62.52  2.02  17.6247  9.8   607.929993  73.62  181.9  345959.0  23.95
# 4      62.52  2.02  17.6247  9.8   602.039978  72.85  181.9  345959.0  24.60
# ...      ...   ...      ...  ...          ...    ...    ...       ...    ...
# 2515  135.28  1.79  25.3952  3.5  1628.099976  51.36  196.7  525810.0  20.15
# 2516  135.28  1.79  25.3952  3.5  1571.900024  49.78  196.7  525810.0  21.95
# 2517  135.28  1.79  25.3952  3.5  1552.760010  48.67  196.7  525810.0  22.45
# 2518  135.28  1.79  25.3952  3.5  1497.869995  47.17  196.7  525810.0  26.60
# 2519  135.28  1.79  25.3952  3.5  1476.430054  44.83  196.7  525810.0  26.10
#
# [2520 rows x 16 columns]

# %%
p=0.9
# cutoff = int(p * len(df))
cutoff = 2300
df_train = df[:cutoff].copy()
df_test = df[cutoff:].copy()

# %%
cutoff
# Out:
# 2300

# %%
df.columns
# Out:
# Index(['ds', 'y', 'fbsp', 'diff', 'tby', 'ffr', 'fta', 'eps', 'div', 'per',
#        'une', 'rus', 'wti', 'ppi', 'rfs', 'vix'],
#       dtype='object')

# %%
possible_features = ['tby', 'ffr', 'fta', 'eps', 'div', 'per',
       'une', 'rus', 'wti', 'ppi', 'rfs', 'vix']

from itertools import chain, combinations

def powerset(iterable):
    #"powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))


#print(list(powerset(possible_features)))

# %%
len(possible_features)
# Out:
# 12

# %%
from statsmodels.regression.linear_model import OLS

reg_new = OLS((df_train['diff']).copy(),df_train[possible_features].copy()).fit()
print(reg_new.params)

#from the output, we can see it's consistent with sklearn output
# Out:
# tby   -139.802399
# ffr     59.572482
# fta     -0.000043
# eps     -7.039736
# div   -309.382346
# per     13.525559
# une     20.759948
# rus      0.795604
# wti      2.286543
# ppi      8.380622
# rfs     -0.002575
# vix     -6.008608
# dtype: float64

# %%
new_coef = reg_new.params
new_possible_feats = new_coef[abs(new_coef)>0].index

power_feats = list(powerset(new_possible_feats))
power_feats.remove(())

power_feats = [ list(feats) for feats in power_feats]
power_feats
# Out:
# [['tby'],
#  ['ffr'],
#  ['fta'],
#  ['eps'],
#  ['div'],
#  ['per'],
#  ['une'],
#  ['rus'],
#  ['wti'],
#  ['ppi'],
#  ['rfs'],
#  ['vix'],
#  ['tby', 'ffr'],
#  ['tby', 'fta'],
#  ['tby', 'eps'],
#  ['tby', 'div'],
#  ['tby', 'per'],
#  ['tby', 'une'],
#  ['tby', 'rus'],
#  ['tby', 'wti'],
#  ['tby', 'ppi'],
#  ['tby', 'rfs'],
#  ['tby', 'vix'],
#  ['ffr', 'fta'],
#  ['ffr', 'eps'],
#  ['ffr', 'div'],
#  ['ffr', 'per'],
#  ['ffr', 'une'],
#  ['ffr', 'rus'],
#  ['ffr', 'wti'],
#  ['ffr', 'ppi'],
#  ['ffr', 'rfs'],
#  ['ffr', 'vix'],
#  ['fta', 'eps'],
#  ['fta', 'div'],
#  ['fta', 'per'],
#  ['fta', 'une'],
#  ['fta', 'rus'],
#  ['fta', 'wti'],
#  ['fta', 'ppi'],
#  ['fta', 'rfs'],
#  ['fta', 'vix'],
#  ['eps', 'div'],
#  ['eps', 'per'],
#  ['eps', 'une'],
#  ['eps', 'rus'],
#  ['eps', 'wti'],
#  ['eps', 'ppi'],
#  ['eps', 'rfs'],
#  ['eps', 'vix'],
#  ['div', 'per'],
#  ['div', 'une'],
#  ['div', 'rus'],
#  ['div', 'wti'],
#  ['div', 'ppi'],
#  ['div', 'rfs'],
#  ['div', 'vix'],
#  ['per', 'une'],
#  ['per', 'rus'],
#  ['per', 'wti'],
#  ['per', 'ppi'],
#  ['per', 'rfs'],
#  ['per', 'vix'],
#  ['une', 'rus'],
#  ['une', 'wti'],
#  ['une', 'ppi'],
#  ['une', 'rfs'],
#  ['une', 'vix'],
#  ['rus', 'wti'],
#  ['rus', 'ppi'],
#  ['rus', 'rfs'],
#  ['rus', 'vix'],
#  ['wti', 'ppi'],
#  ['wti', 'rfs'],
#  ['wti', 'vix'],
#  ['ppi', 'rfs'],
#  ['ppi', 'vix'],
#  ['rfs', 'vix'],
#  ['tby', 'ffr', 'fta'],
#  ['tby', 'ffr', 'eps'],
#  ['tby', 'ffr', 'div'],
#  ['tby', 'ffr', 'per'],
#  ['tby', 'ffr', 'une'],
#  ['tby', 'ffr', 'rus'],
#  ['tby', 'ffr', 'wti'],
#  ['tby', 'ffr', 'ppi'],
#  ['tby', 'ffr', 'rfs'],
#  ['tby', 'ffr', 'vix'],
#  ['tby', 'fta', 'eps'],
#  ['tby', 'fta', 'div'],
#  ['tby', 'fta', 'per'],
#  ['tby', 'fta', 'une'],
#  ['tby', 'fta', 'rus'],
#  ['tby', 'fta', 'wti'],
#  ['tby', 'fta', 'ppi'],
#  ['tby', 'fta', 'rfs'],
#  ['tby', 'fta', 'vix'],
#  ['tby', 'eps', 'div'],
#  ['tby', 'eps', 'per'],
#  ['tby', 'eps', 'une'],
#  ['tby', 'eps', 'rus'],
#  ['tby', 'eps', 'wti'],
#  ['tby', 'eps', 'ppi'],
#  ['tby', 'eps', 'rfs'],
#  ['tby', 'eps', 'vix'],
#  ['tby', 'div', 'per'],
#  ['tby', 'div', 'une'],
#  ['tby', 'div', 'rus'],
#  ['tby', 'div', 'wti'],
#  ['tby', 'div', 'ppi'],
#  ['tby', 'div', 'rfs'],
#  ['tby', 'div', 'vix'],
#  ['tby', 'per', 'une'],
#  ['tby', 'per', 'rus'],
#  ['tby', 'per', 'wti'],
#  ['tby', 'per', 'ppi'],
#  ['tby', 'per', 'rfs'],
#  ['tby', 'per', 'vix'],
#  ['tby', 'une', 'rus'],
#  ['tby', 'une', 'wti'],
#  ['tby', 'une', 'ppi'],
#  ['tby', 'une', 'rfs'],
#  ['tby', 'une', 'vix'],
#  ['tby', 'rus', 'wti'],
#  ['tby', 'rus', 'ppi'],
#  ['tby', 'rus', 'rfs'],
#  ['tby', 'rus', 'vix'],
#  ['tby', 'wti', 'ppi'],
#  ['tby', 'wti', 'rfs'],
#  ['tby', 'wti', 'vix'],
#  ['tby', 'ppi', 'rfs'],
#  ['tby', 'ppi', 'vix'],
#  ['tby', 'rfs', 'vix'],
#  ['ffr', 'fta', 'eps'],
#  ['ffr', 'fta', 'div'],
#  ['ffr', 'fta', 'per'],
#  ['ffr', 'fta', 'une'],
#  ['ffr', 'fta', 'rus'],
#  ['ffr', 'fta', 'wti'],
#  ['ffr', 'fta', 'ppi'],
#  ['ffr', 'fta', 'rfs'],
#  ['ffr', 'fta', 'vix'],
#  ['ffr', 'eps', 'div'],
#  ['ffr', 'eps', 'per'],
#  ['ffr', 'eps', 'une'],
#  ['ffr', 'eps', 'rus'],
#  ['ffr', 'eps', 'wti'],
#  ['ffr', 'eps', 'ppi'],
#  ['ffr', 'eps', 'rfs'],
#  ['ffr', 'eps', 'vix'],
#  ['ffr', 'div', 'per'],
#  ['ffr', 'div', 'une'],
#  ['ffr', 'div', 'rus'],
#  ['ffr', 'div', 'wti'],
#  ['ffr', 'div', 'ppi'],
#  ['ffr', 'div', 'rfs'],
#  ['ffr', 'div', 'vix'],
#  ['ffr', 'per', 'une'],
#  ['ffr', 'per', 'rus'],
#  ['ffr', 'per', 'wti'],
#  ['ffr', 'per', 'ppi'],
#  ['ffr', 'per', 'rfs'],
#  ['ffr', 'per', 'vix'],
#  ['ffr', 'une', 'rus'],
#  ['ffr', 'une', 'wti'],
#  ['ffr', 'une', 'ppi'],
#  ['ffr', 'une', 'rfs'],
#  ['ffr', 'une', 'vix'],
#  ['ffr', 'rus', 'wti'],
#  ['ffr', 'rus', 'ppi'],
#  ['ffr', 'rus', 'rfs'],
#  ['ffr', 'rus', 'vix'],
#  ['ffr', 'wti', 'ppi'],
#  ['ffr', 'wti', 'rfs'],
#  ['ffr', 'wti', 'vix'],
#  ['ffr', 'ppi', 'rfs'],
#  ['ffr', 'ppi', 'vix'],
#  ['ffr', 'rfs', 'vix'],
#  ['fta', 'eps', 'div'],
#  ['fta', 'eps', 'per'],
#  ['fta', 'eps', 'une'],
#  ['fta', 'eps', 'rus'],
#  ['fta', 'eps', 'wti'],
#  ['fta', 'eps', 'ppi'],
#  ['fta', 'eps', 'rfs'],
#  ['fta', 'eps', 'vix'],
#  ['fta', 'div', 'per'],
#  ['fta', 'div', 'une'],
#  ['fta', 'div', 'rus'],
#  ['fta', 'div', 'wti'],
#  ['fta', 'div', 'ppi'],
#  ['fta', 'div', 'rfs'],
#  ['fta', 'div', 'vix'],
#  ['fta', 'per', 'une'],
#  ['fta', 'per', 'rus'],
#  ['fta', 'per', 'wti'],
#  ['fta', 'per', 'ppi'],
#  ['fta', 'per', 'rfs'],
#  ['fta', 'per', 'vix'],
#  ['fta', 'une', 'rus'],
#  ['fta', 'une', 'wti'],
#  ['fta', 'une', 'ppi'],
#  ['fta', 'une', 'rfs'],
#  ['fta', 'une', 'vix'],
#  ['fta', 'rus', 'wti'],
#  ['fta', 'rus', 'ppi'],
#  ['fta', 'rus', 'rfs'],
#  ['fta', 'rus', 'vix'],
#  ['fta', 'wti', 'ppi'],
#  ['fta', 'wti', 'rfs'],
#  ['fta', 'wti', 'vix'],
#  ['fta', 'ppi', 'rfs'],
#  ['fta', 'ppi', 'vix'],
#  ['fta', 'rfs', 'vix'],
#  ['eps', 'div', 'per'],
#  ['eps', 'div', 'une'],
#  ['eps', 'div', 'rus'],
#  ['eps', 'div', 'wti'],
#  ['eps', 'div', 'ppi'],
#  ['eps', 'div', 'rfs'],
#  ['eps', 'div', 'vix'],
#  ['eps', 'per', 'une'],
#  ['eps', 'per', 'rus'],
#  ['eps', 'per', 'wti'],
#  ['eps', 'per', 'ppi'],
#  ['eps', 'per', 'rfs'],
#  ['eps', 'per', 'vix'],
#  ['eps', 'une', 'rus'],
#  ['eps', 'une', 'wti'],
#  ['eps', 'une', 'ppi'],
#  ['eps', 'une', 'rfs'],
#  ['eps', 'une', 'vix'],
#  ['eps', 'rus', 'wti'],
#  ['eps', 'rus', 'ppi'],
#  ['eps', 'rus', 'rfs'],
#  ['eps', 'rus', 'vix'],
#  ['eps', 'wti', 'ppi'],
#  ['eps', 'wti', 'rfs'],
#  ['eps', 'wti', 'vix'],
#  ['eps', 'ppi', 'rfs'],
#  ['eps', 'ppi', 'vix'],
#  ['eps', 'rfs', 'vix'],
#  ['div', 'per', 'une'],
#  ['div', 'per', 'rus'],
#  ['div', 'per', 'wti'],
#  ['div', 'per', 'ppi'],
#  ['div', 'per', 'rfs'],
#  ['div', 'per', 'vix'],
#  ['div', 'une', 'rus'],
#  ['div', 'une', 'wti'],
#  ['div', 'une', 'ppi'],
#  ['div', 'une', 'rfs'],
#  ['div', 'une', 'vix'],
#  ['div', 'rus', 'wti'],
#  ['div', 'rus', 'ppi'],
#  ['div', 'rus', 'rfs'],
#  ['div', 'rus', 'vix'],
#  ['div', 'wti', 'ppi'],
#  ['div', 'wti', 'rfs'],
#  ['div', 'wti', 'vix'],
#  ['div', 'ppi', 'rfs'],
#  ['div', 'ppi', 'vix'],
#  ['div', 'rfs', 'vix'],
#  ['per', 'une', 'rus'],
#  ['per', 'une', 'wti'],
#  ['per', 'une', 'ppi'],
#  ['per', 'une', 'rfs'],
#  ['per', 'une', 'vix'],
#  ['per', 'rus', 'wti'],
#  ['per', 'rus', 'ppi'],
#  ['per', 'rus', 'rfs'],
#  ['per', 'rus', 'vix'],
#  ['per', 'wti', 'ppi'],
#  ['per', 'wti', 'rfs'],
#  ['per', 'wti', 'vix'],
#  ['per', 'ppi', 'rfs'],
#  ['per', 'ppi', 'vix'],
#  ['per', 'rfs', 'vix'],
#  ['une', 'rus', 'wti'],
#  ['une', 'rus', 'ppi'],
#  ['une', 'rus', 'rfs'],
#  ['une', 'rus', 'vix'],
#  ['une', 'wti', 'ppi'],
#  ['une', 'wti', 'rfs'],
#  ['une', 'wti', 'vix'],
#  ['une', 'ppi', 'rfs'],
#  ['une', 'ppi', 'vix'],
#  ['une', 'rfs', 'vix'],
#  ['rus', 'wti', 'ppi'],
#  ['rus', 'wti', 'rfs'],
#  ['rus', 'wti', 'vix'],
#  ['rus', 'ppi', 'rfs'],
#  ['rus', 'ppi', 'vix'],
#  ['rus', 'rfs', 'vix'],
#  ['wti', 'ppi', 'rfs'],
#  ['wti', 'ppi', 'vix'],
#  ['wti', 'rfs', 'vix'],
#  ['ppi', 'rfs', 'vix'],
#  ['tby', 'ffr', 'fta', 'eps'],
#  ['tby', 'ffr', 'fta', 'div'],
#  ['tby', 'ffr', 'fta', 'per'],
#  ['tby', 'ffr', 'fta', 'une'],
#  ['tby', 'ffr', 'fta', 'rus'],
#  ['tby', 'ffr', 'fta', 'wti'],
#  ['tby', 'ffr', 'fta', 'ppi'],
#  ['tby', 'ffr', 'fta', 'rfs'],
#  ['tby', 'ffr', 'fta', 'vix'],
#  ['tby', 'ffr', 'eps', 'div'],
#  ['tby', 'ffr', 'eps', 'per'],
#  ['tby', 'ffr', 'eps', 'une'],
#  ['tby', 'ffr', 'eps', 'rus'],
#  ['tby', 'ffr', 'eps', 'wti'],
#  ['tby', 'ffr', 'eps', 'ppi'],
#  ['tby', 'ffr', 'eps', 'rfs'],
#  ['tby', 'ffr', 'eps', 'vix'],
#  ['tby', 'ffr', 'div', 'per'],
#  ['tby', 'ffr', 'div', 'une'],
#  ['tby', 'ffr', 'div', 'rus'],
#  ['tby', 'ffr', 'div', 'wti'],
#  ['tby', 'ffr', 'div', 'ppi'],
#  ['tby', 'ffr', 'div', 'rfs'],
#  ['tby', 'ffr', 'div', 'vix'],
#  ['tby', 'ffr', 'per', 'une'],
#  ['tby', 'ffr', 'per', 'rus'],
#  ['tby', 'ffr', 'per', 'wti'],
#  ['tby', 'ffr', 'per', 'ppi'],
#  ['tby', 'ffr', 'per', 'rfs'],
#  ['tby', 'ffr', 'per', 'vix'],
#  ['tby', 'ffr', 'une', 'rus'],
#  ['tby', 'ffr', 'une', 'wti'],
#  ['tby', 'ffr', 'une', 'ppi'],
#  ['tby', 'ffr', 'une', 'rfs'],
#  ['tby', 'ffr', 'une', 'vix'],
#  ['tby', 'ffr', 'rus', 'wti'],
#  ['tby', 'ffr', 'rus', 'ppi'],
#  ['tby', 'ffr', 'rus', 'rfs'],
#  ['tby', 'ffr', 'rus', 'vix'],
#  ['tby', 'ffr', 'wti', 'ppi'],
#  ['tby', 'ffr', 'wti', 'rfs'],
#  ['tby', 'ffr', 'wti', 'vix'],
#  ['tby', 'ffr', 'ppi', 'rfs'],
#  ['tby', 'ffr', 'ppi', 'vix'],
#  ['tby', 'ffr', 'rfs', 'vix'],
#  ['tby', 'fta', 'eps', 'div'],
#  ['tby', 'fta', 'eps', 'per'],
#  ['tby', 'fta', 'eps', 'une'],
#  ['tby', 'fta', 'eps', 'rus'],
#  ['tby', 'fta', 'eps', 'wti'],
#  ['tby', 'fta', 'eps', 'ppi'],
#  ['tby', 'fta', 'eps', 'rfs'],
#  ['tby', 'fta', 'eps', 'vix'],
#  ['tby', 'fta', 'div', 'per'],
#  ['tby', 'fta', 'div', 'une'],
#  ['tby', 'fta', 'div', 'rus'],
#  ['tby', 'fta', 'div', 'wti'],
#  ['tby', 'fta', 'div', 'ppi'],
#  ['tby', 'fta', 'div', 'rfs'],
#  ['tby', 'fta', 'div', 'vix'],
#  ['tby', 'fta', 'per', 'une'],
#  ['tby', 'fta', 'per', 'rus'],
#  ['tby', 'fta', 'per', 'wti'],
#  ['tby', 'fta', 'per', 'ppi'],
#  ['tby', 'fta', 'per', 'rfs'],
#  ['tby', 'fta', 'per', 'vix'],
#  ['tby', 'fta', 'une', 'rus'],
#  ['tby', 'fta', 'une', 'wti'],
#  ['tby', 'fta', 'une', 'ppi'],
#  ['tby', 'fta', 'une', 'rfs'],
#  ['tby', 'fta', 'une', 'vix'],
#  ['tby', 'fta', 'rus', 'wti'],
#  ['tby', 'fta', 'rus', 'ppi'],
#  ['tby', 'fta', 'rus', 'rfs'],
#  ['tby', 'fta', 'rus', 'vix'],
#  ['tby', 'fta', 'wti', 'ppi'],
#  ['tby', 'fta', 'wti', 'rfs'],
#  ['tby', 'fta', 'wti', 'vix'],
#  ['tby', 'fta', 'ppi', 'rfs'],
#  ['tby', 'fta', 'ppi', 'vix'],
#  ['tby', 'fta', 'rfs', 'vix'],
#  ['tby', 'eps', 'div', 'per'],
#  ['tby', 'eps', 'div', 'une'],
#  ['tby', 'eps', 'div', 'rus'],
#  ['tby', 'eps', 'div', 'wti'],
#  ['tby', 'eps', 'div', 'ppi'],
#  ['tby', 'eps', 'div', 'rfs'],
#  ['tby', 'eps', 'div', 'vix'],
#  ['tby', 'eps', 'per', 'une'],
#  ['tby', 'eps', 'per', 'rus'],
#  ['tby', 'eps', 'per', 'wti'],
#  ['tby', 'eps', 'per', 'ppi'],
#  ['tby', 'eps', 'per', 'rfs'],
#  ['tby', 'eps', 'per', 'vix'],
#  ['tby', 'eps', 'une', 'rus'],
#  ['tby', 'eps', 'une', 'wti'],
#  ['tby', 'eps', 'une', 'ppi'],
#  ['tby', 'eps', 'une', 'rfs'],
#  ['tby', 'eps', 'une', 'vix'],
#  ['tby', 'eps', 'rus', 'wti'],
#  ['tby', 'eps', 'rus', 'ppi'],
#  ['tby', 'eps', 'rus', 'rfs'],
#  ['tby', 'eps', 'rus', 'vix'],
#  ['tby', 'eps', 'wti', 'ppi'],
#  ['tby', 'eps', 'wti', 'rfs'],
#  ['tby', 'eps', 'wti', 'vix'],
#  ['tby', 'eps', 'ppi', 'rfs'],
#  ['tby', 'eps', 'ppi', 'vix'],
#  ['tby', 'eps', 'rfs', 'vix'],
#  ['tby', 'div', 'per', 'une'],
#  ['tby', 'div', 'per', 'rus'],
#  ['tby', 'div', 'per', 'wti'],
#  ['tby', 'div', 'per', 'ppi'],
#  ['tby', 'div', 'per', 'rfs'],
#  ['tby', 'div', 'per', 'vix'],
#  ['tby', 'div', 'une', 'rus'],
#  ['tby', 'div', 'une', 'wti'],
#  ['tby', 'div', 'une', 'ppi'],
#  ['tby', 'div', 'une', 'rfs'],
#  ['tby', 'div', 'une', 'vix'],
#  ['tby', 'div', 'rus', 'wti'],
#  ['tby', 'div', 'rus', 'ppi'],
#  ['tby', 'div', 'rus', 'rfs'],
#  ['tby', 'div', 'rus', 'vix'],
#  ['tby', 'div', 'wti', 'ppi'],
#  ['tby', 'div', 'wti', 'rfs'],
#  ['tby', 'div', 'wti', 'vix'],
#  ['tby', 'div', 'ppi', 'rfs'],
#  ['tby', 'div', 'ppi', 'vix'],
#  ['tby', 'div', 'rfs', 'vix'],
#  ['tby', 'per', 'une', 'rus'],
#  ['tby', 'per', 'une', 'wti'],
#  ['tby', 'per', 'une', 'ppi'],
#  ['tby', 'per', 'une', 'rfs'],
#  ['tby', 'per', 'une', 'vix'],
#  ['tby', 'per', 'rus', 'wti'],
#  ['tby', 'per', 'rus', 'ppi'],
#  ['tby', 'per', 'rus', 'rfs'],
#  ['tby', 'per', 'rus', 'vix'],
#  ['tby', 'per', 'wti', 'ppi'],
#  ['tby', 'per', 'wti', 'rfs'],
#  ['tby', 'per', 'wti', 'vix'],
#  ['tby', 'per', 'ppi', 'rfs'],
#  ['tby', 'per', 'ppi', 'vix'],
#  ['tby', 'per', 'rfs', 'vix'],
#  ['tby', 'une', 'rus', 'wti'],
#  ['tby', 'une', 'rus', 'ppi'],
#  ['tby', 'une', 'rus', 'rfs'],
#  ['tby', 'une', 'rus', 'vix'],
#  ['tby', 'une', 'wti', 'ppi'],
#  ['tby', 'une', 'wti', 'rfs'],
#  ['tby', 'une', 'wti', 'vix'],
#  ['tby', 'une', 'ppi', 'rfs'],
#  ['tby', 'une', 'ppi', 'vix'],
#  ['tby', 'une', 'rfs', 'vix'],
#  ['tby', 'rus', 'wti', 'ppi'],
#  ['tby', 'rus', 'wti', 'rfs'],
#  ['tby', 'rus', 'wti', 'vix'],
#  ['tby', 'rus', 'ppi', 'rfs'],
#  ['tby', 'rus', 'ppi', 'vix'],
#  ['tby', 'rus', 'rfs', 'vix'],
#  ['tby', 'wti', 'ppi', 'rfs'],
#  ['tby', 'wti', 'ppi', 'vix'],
#  ['tby', 'wti', 'rfs', 'vix'],
#  ['tby', 'ppi', 'rfs', 'vix'],
#  ['ffr', 'fta', 'eps', 'div'],
#  ['ffr', 'fta', 'eps', 'per'],
#  ['ffr', 'fta', 'eps', 'une'],
#  ['ffr', 'fta', 'eps', 'rus'],
#  ['ffr', 'fta', 'eps', 'wti'],
#  ['ffr', 'fta', 'eps', 'ppi'],
#  ['ffr', 'fta', 'eps', 'rfs'],
#  ['ffr', 'fta', 'eps', 'vix'],
#  ['ffr', 'fta', 'div', 'per'],
#  ['ffr', 'fta', 'div', 'une'],
#  ['ffr', 'fta', 'div', 'rus'],
#  ['ffr', 'fta', 'div', 'wti'],
#  ['ffr', 'fta', 'div', 'ppi'],
#  ['ffr', 'fta', 'div', 'rfs'],
#  ['ffr', 'fta', 'div', 'vix'],
#  ['ffr', 'fta', 'per', 'une'],
#  ['ffr', 'fta', 'per', 'rus'],
#  ['ffr', 'fta', 'per', 'wti'],
#  ['ffr', 'fta', 'per', 'ppi'],
#  ['ffr', 'fta', 'per', 'rfs'],
#  ['ffr', 'fta', 'per', 'vix'],
#  ['ffr', 'fta', 'une', 'rus'],
#  ['ffr', 'fta', 'une', 'wti'],
#  ['ffr', 'fta', 'une', 'ppi'],
#  ['ffr', 'fta', 'une', 'rfs'],
#  ['ffr', 'fta', 'une', 'vix'],
#  ['ffr', 'fta', 'rus', 'wti'],
#  ['ffr', 'fta', 'rus', 'ppi'],
#  ['ffr', 'fta', 'rus', 'rfs'],
#  ['ffr', 'fta', 'rus', 'vix'],
#  ['ffr', 'fta', 'wti', 'ppi'],
#  ['ffr', 'fta', 'wti', 'rfs'],
#  ['ffr', 'fta', 'wti', 'vix'],
#  ['ffr', 'fta', 'ppi', 'rfs'],
#  ['ffr', 'fta', 'ppi', 'vix'],
#  ['ffr', 'fta', 'rfs', 'vix'],
#  ['ffr', 'eps', 'div', 'per'],
#  ['ffr', 'eps', 'div', 'une'],
#  ['ffr', 'eps', 'div', 'rus'],
#  ['ffr', 'eps', 'div', 'wti'],
#  ['ffr', 'eps', 'div', 'ppi'],
#  ['ffr', 'eps', 'div', 'rfs'],
#  ['ffr', 'eps', 'div', 'vix'],
#  ['ffr', 'eps', 'per', 'une'],
#  ['ffr', 'eps', 'per', 'rus'],
#  ['ffr', 'eps', 'per', 'wti'],
#  ['ffr', 'eps', 'per', 'ppi'],
#  ['ffr', 'eps', 'per', 'rfs'],
#  ['ffr', 'eps', 'per', 'vix'],
#  ['ffr', 'eps', 'une', 'rus'],
#  ['ffr', 'eps', 'une', 'wti'],
#  ['ffr', 'eps', 'une', 'ppi'],
#  ['ffr', 'eps', 'une', 'rfs'],
#  ['ffr', 'eps', 'une', 'vix'],
#  ['ffr', 'eps', 'rus', 'wti'],
#  ['ffr', 'eps', 'rus', 'ppi'],
#  ['ffr', 'eps', 'rus', 'rfs'],
#  ['ffr', 'eps', 'rus', 'vix'],
#  ['ffr', 'eps', 'wti', 'ppi'],
#  ['ffr', 'eps', 'wti', 'rfs'],
#  ['ffr', 'eps', 'wti', 'vix'],
#  ['ffr', 'eps', 'ppi', 'rfs'],
#  ['ffr', 'eps', 'ppi', 'vix'],
#  ['ffr', 'eps', 'rfs', 'vix'],
#  ['ffr', 'div', 'per', 'une'],
#  ['ffr', 'div', 'per', 'rus'],
#  ['ffr', 'div', 'per', 'wti'],
#  ['ffr', 'div', 'per', 'ppi'],
#  ['ffr', 'div', 'per', 'rfs'],
#  ['ffr', 'div', 'per', 'vix'],
#  ['ffr', 'div', 'une', 'rus'],
#  ['ffr', 'div', 'une', 'wti'],
#  ['ffr', 'div', 'une', 'ppi'],
#  ['ffr', 'div', 'une', 'rfs'],
#  ['ffr', 'div', 'une', 'vix'],
#  ['ffr', 'div', 'rus', 'wti'],
#  ['ffr', 'div', 'rus', 'ppi'],
#  ['ffr', 'div', 'rus', 'rfs'],
#  ['ffr', 'div', 'rus', 'vix'],
#  ['ffr', 'div', 'wti', 'ppi'],
#  ['ffr', 'div', 'wti', 'rfs'],
#  ['ffr', 'div', 'wti', 'vix'],
#  ['ffr', 'div', 'ppi', 'rfs'],
#  ['ffr', 'div', 'ppi', 'vix'],
#  ['ffr', 'div', 'rfs', 'vix'],
#  ['ffr', 'per', 'une', 'rus'],
#  ['ffr', 'per', 'une', 'wti'],
#  ['ffr', 'per', 'une', 'ppi'],
#  ['ffr', 'per', 'une', 'rfs'],
#  ['ffr', 'per', 'une', 'vix'],
#  ['ffr', 'per', 'rus', 'wti'],
#  ['ffr', 'per', 'rus', 'ppi'],
#  ['ffr', 'per', 'rus', 'rfs'],
#  ['ffr', 'per', 'rus', 'vix'],
#  ['ffr', 'per', 'wti', 'ppi'],
#  ['ffr', 'per', 'wti', 'rfs'],
#  ['ffr', 'per', 'wti', 'vix'],
#  ['ffr', 'per', 'ppi', 'rfs'],
#  ['ffr', 'per', 'ppi', 'vix'],
#  ['ffr', 'per', 'rfs', 'vix'],
#  ['ffr', 'une', 'rus', 'wti'],
#  ['ffr', 'une', 'rus', 'ppi'],
#  ['ffr', 'une', 'rus', 'rfs'],
#  ['ffr', 'une', 'rus', 'vix'],
#  ['ffr', 'une', 'wti', 'ppi'],
#  ['ffr', 'une', 'wti', 'rfs'],
#  ['ffr', 'une', 'wti', 'vix'],
#  ['ffr', 'une', 'ppi', 'rfs'],
#  ['ffr', 'une', 'ppi', 'vix'],
#  ['ffr', 'une', 'rfs', 'vix'],
#  ['ffr', 'rus', 'wti', 'ppi'],
#  ['ffr', 'rus', 'wti', 'rfs'],
#  ['ffr', 'rus', 'wti', 'vix'],
#  ['ffr', 'rus', 'ppi', 'rfs'],
#  ['ffr', 'rus', 'ppi', 'vix'],
#  ['ffr', 'rus', 'rfs', 'vix'],
#  ['ffr', 'wti', 'ppi', 'rfs'],
#  ['ffr', 'wti', 'ppi', 'vix'],
#  ['ffr', 'wti', 'rfs', 'vix'],
#  ['ffr', 'ppi', 'rfs', 'vix'],
#  ['fta', 'eps', 'div', 'per'],
#  ['fta', 'eps', 'div', 'une'],
#  ['fta', 'eps', 'div', 'rus'],
#  ['fta', 'eps', 'div', 'wti'],
#  ['fta', 'eps', 'div', 'ppi'],
#  ['fta', 'eps', 'div', 'rfs'],
#  ['fta', 'eps', 'div', 'vix'],
#  ['fta', 'eps', 'per', 'une'],
#  ['fta', 'eps', 'per', 'rus'],
#  ['fta', 'eps', 'per', 'wti'],
#  ['fta', 'eps', 'per', 'ppi'],
#  ['fta', 'eps', 'per', 'rfs'],
#  ['fta', 'eps', 'per', 'vix'],
#  ['fta', 'eps', 'une', 'rus'],
#  ['fta', 'eps', 'une', 'wti'],
#  ['fta', 'eps', 'une', 'ppi'],
#  ['fta', 'eps', 'une', 'rfs'],
#  ['fta', 'eps', 'une', 'vix'],
#  ['fta', 'eps', 'rus', 'wti'],
#  ['fta', 'eps', 'rus', 'ppi'],
#  ['fta', 'eps', 'rus', 'rfs'],
#  ['fta', 'eps', 'rus', 'vix'],
#  ['fta', 'eps', 'wti', 'ppi'],
#  ['fta', 'eps', 'wti', 'rfs'],
#  ['fta', 'eps', 'wti', 'vix'],
#  ['fta', 'eps', 'ppi', 'rfs'],
#  ['fta', 'eps', 'ppi', 'vix'],
#  ['fta', 'eps', 'rfs', 'vix'],
#  ['fta', 'div', 'per', 'une'],
#  ['fta', 'div', 'per', 'rus'],
#  ['fta', 'div', 'per', 'wti'],
#  ['fta', 'div', 'per', 'ppi'],
#  ['fta', 'div', 'per', 'rfs'],
#  ['fta', 'div', 'per', 'vix'],
#  ['fta', 'div', 'une', 'rus'],
#  ['fta', 'div', 'une', 'wti'],
#  ['fta', 'div', 'une', 'ppi'],
#  ['fta', 'div', 'une', 'rfs'],
#  ['fta', 'div', 'une', 'vix'],
#  ['fta', 'div', 'rus', 'wti'],
#  ['fta', 'div', 'rus', 'ppi'],
#  ['fta', 'div', 'rus', 'rfs'],
#  ['fta', 'div', 'rus', 'vix'],
#  ['fta', 'div', 'wti', 'ppi'],
#  ['fta', 'div', 'wti', 'rfs'],
#  ['fta', 'div', 'wti', 'vix'],
#  ['fta', 'div', 'ppi', 'rfs'],
#  ['fta', 'div', 'ppi', 'vix'],
#  ['fta', 'div', 'rfs', 'vix'],
#  ['fta', 'per', 'une', 'rus'],
#  ['fta', 'per', 'une', 'wti'],
#  ['fta', 'per', 'une', 'ppi'],
#  ['fta', 'per', 'une', 'rfs'],
#  ['fta', 'per', 'une', 'vix'],
#  ['fta', 'per', 'rus', 'wti'],
#  ['fta', 'per', 'rus', 'ppi'],
#  ['fta', 'per', 'rus', 'rfs'],
#  ['fta', 'per', 'rus', 'vix'],
#  ['fta', 'per', 'wti', 'ppi'],
#  ['fta', 'per', 'wti', 'rfs'],
#  ['fta', 'per', 'wti', 'vix'],
#  ['fta', 'per', 'ppi', 'rfs'],
#  ['fta', 'per', 'ppi', 'vix'],
#  ['fta', 'per', 'rfs', 'vix'],
#  ['fta', 'une', 'rus', 'wti'],
#  ['fta', 'une', 'rus', 'ppi'],
#  ['fta', 'une', 'rus', 'rfs'],
#  ['fta', 'une', 'rus', 'vix'],
#  ['fta', 'une', 'wti', 'ppi'],
#  ['fta', 'une', 'wti', 'rfs'],
#  ['fta', 'une', 'wti', 'vix'],
#  ['fta', 'une', 'ppi', 'rfs'],
#  ['fta', 'une', 'ppi', 'vix'],
#  ['fta', 'une', 'rfs', 'vix'],
#  ['fta', 'rus', 'wti', 'ppi'],
#  ['fta', 'rus', 'wti', 'rfs'],
#  ['fta', 'rus', 'wti', 'vix'],
#  ['fta', 'rus', 'ppi', 'rfs'],
#  ['fta', 'rus', 'ppi', 'vix'],
#  ['fta', 'rus', 'rfs', 'vix'],
#  ['fta', 'wti', 'ppi', 'rfs'],
#  ['fta', 'wti', 'ppi', 'vix'],
#  ['fta', 'wti', 'rfs', 'vix'],
#  ['fta', 'ppi', 'rfs', 'vix'],
#  ['eps', 'div', 'per', 'une'],
#  ['eps', 'div', 'per', 'rus'],
#  ['eps', 'div', 'per', 'wti'],
#  ['eps', 'div', 'per', 'ppi'],
#  ['eps', 'div', 'per', 'rfs'],
#  ['eps', 'div', 'per', 'vix'],
#  ['eps', 'div', 'une', 'rus'],
#  ['eps', 'div', 'une', 'wti'],
#  ['eps', 'div', 'une', 'ppi'],
#  ['eps', 'div', 'une', 'rfs'],
#  ['eps', 'div', 'une', 'vix'],
#  ['eps', 'div', 'rus', 'wti'],
#  ['eps', 'div', 'rus', 'ppi'],
#  ['eps', 'div', 'rus', 'rfs'],
#  ['eps', 'div', 'rus', 'vix'],
#  ['eps', 'div', 'wti', 'ppi'],
#  ['eps', 'div', 'wti', 'rfs'],
#  ['eps', 'div', 'wti', 'vix'],
#  ['eps', 'div', 'ppi', 'rfs'],
#  ['eps', 'div', 'ppi', 'vix'],
#  ['eps', 'div', 'rfs', 'vix'],
#  ['eps', 'per', 'une', 'rus'],
#  ['eps', 'per', 'une', 'wti'],
#  ['eps', 'per', 'une', 'ppi'],
#  ['eps', 'per', 'une', 'rfs'],
#  ['eps', 'per', 'une', 'vix'],
#  ['eps', 'per', 'rus', 'wti'],
#  ['eps', 'per', 'rus', 'ppi'],
#  ['eps', 'per', 'rus', 'rfs'],
#  ['eps', 'per', 'rus', 'vix'],
#  ['eps', 'per', 'wti', 'ppi'],
#  ['eps', 'per', 'wti', 'rfs'],
#  ['eps', 'per', 'wti', 'vix'],
#  ['eps', 'per', 'ppi', 'rfs'],
#  ['eps', 'per', 'ppi', 'vix'],
#  ['eps', 'per', 'rfs', 'vix'],
#  ['eps', 'une', 'rus', 'wti'],
#  ['eps', 'une', 'rus', 'ppi'],
#  ['eps', 'une', 'rus', 'rfs'],
#  ['eps', 'une', 'rus', 'vix'],
#  ['eps', 'une', 'wti', 'ppi'],
#  ['eps', 'une', 'wti', 'rfs'],
#  ['eps', 'une', 'wti', 'vix'],
#  ['eps', 'une', 'ppi', 'rfs'],
#  ['eps', 'une', 'ppi', 'vix'],
#  ['eps', 'une', 'rfs', 'vix'],
#  ['eps', 'rus', 'wti', 'ppi'],
#  ['eps', 'rus', 'wti', 'rfs'],
#  ['eps', 'rus', 'wti', 'vix'],
#  ['eps', 'rus', 'ppi', 'rfs'],
#  ['eps', 'rus', 'ppi', 'vix'],
#  ['eps', 'rus', 'rfs', 'vix'],
#  ['eps', 'wti', 'ppi', 'rfs'],
#  ['eps', 'wti', 'ppi', 'vix'],
#  ['eps', 'wti', 'rfs', 'vix'],
#  ['eps', 'ppi', 'rfs', 'vix'],
#  ['div', 'per', 'une', 'rus'],
#  ['div', 'per', 'une', 'wti'],
#  ['div', 'per', 'une', 'ppi'],
#  ['div', 'per', 'une', 'rfs'],
#  ['div', 'per', 'une', 'vix'],
#  ['div', 'per', 'rus', 'wti'],
#  ['div', 'per', 'rus', 'ppi'],
#  ['div', 'per', 'rus', 'rfs'],
#  ['div', 'per', 'rus', 'vix'],
#  ['div', 'per', 'wti', 'ppi'],
#  ['div', 'per', 'wti', 'rfs'],
#  ['div', 'per', 'wti', 'vix'],
#  ['div', 'per', 'ppi', 'rfs'],
#  ['div', 'per', 'ppi', 'vix'],
#  ['div', 'per', 'rfs', 'vix'],
#  ['div', 'une', 'rus', 'wti'],
#  ['div', 'une', 'rus', 'ppi'],
#  ['div', 'une', 'rus', 'rfs'],
#  ['div', 'une', 'rus', 'vix'],
#  ['div', 'une', 'wti', 'ppi'],
#  ['div', 'une', 'wti', 'rfs'],
#  ['div', 'une', 'wti', 'vix'],
#  ['div', 'une', 'ppi', 'rfs'],
#  ['div', 'une', 'ppi', 'vix'],
#  ['div', 'une', 'rfs', 'vix'],
#  ['div', 'rus', 'wti', 'ppi'],
#  ['div', 'rus', 'wti', 'rfs'],
#  ['div', 'rus', 'wti', 'vix'],
#  ['div', 'rus', 'ppi', 'rfs'],
#  ['div', 'rus', 'ppi', 'vix'],
#  ['div', 'rus', 'rfs', 'vix'],
#  ['div', 'wti', 'ppi', 'rfs'],
#  ['div', 'wti', 'ppi', 'vix'],
#  ['div', 'wti', 'rfs', 'vix'],
#  ['div', 'ppi', 'rfs', 'vix'],
#  ['per', 'une', 'rus', 'wti'],
#  ['per', 'une', 'rus', 'ppi'],
#  ['per', 'une', 'rus', 'rfs'],
#  ['per', 'une', 'rus', 'vix'],
#  ['per', 'une', 'wti', 'ppi'],
#  ['per', 'une', 'wti', 'rfs'],
#  ['per', 'une', 'wti', 'vix'],
#  ['per', 'une', 'ppi', 'rfs'],
#  ['per', 'une', 'ppi', 'vix'],
#  ['per', 'une', 'rfs', 'vix'],
#  ['per', 'rus', 'wti', 'ppi'],
#  ['per', 'rus', 'wti', 'rfs'],
#  ['per', 'rus', 'wti', 'vix'],
#  ['per', 'rus', 'ppi', 'rfs'],
#  ['per', 'rus', 'ppi', 'vix'],
#  ['per', 'rus', 'rfs', 'vix'],
#  ['per', 'wti', 'ppi', 'rfs'],
#  ['per', 'wti', 'ppi', 'vix'],
#  ['per', 'wti', 'rfs', 'vix'],
#  ['per', 'ppi', 'rfs', 'vix'],
#  ['une', 'rus', 'wti', 'ppi'],
#  ['une', 'rus', 'wti', 'rfs'],
#  ['une', 'rus', 'wti', 'vix'],
#  ['une', 'rus', 'ppi', 'rfs'],
#  ['une', 'rus', 'ppi', 'vix'],
#  ['une', 'rus', 'rfs', 'vix'],
#  ['une', 'wti', 'ppi', 'rfs'],
#  ['une', 'wti', 'ppi', 'vix'],
#  ['une', 'wti', 'rfs', 'vix'],
#  ['une', 'ppi', 'rfs', 'vix'],
#  ['rus', 'wti', 'ppi', 'rfs'],
#  ['rus', 'wti', 'ppi', 'vix'],
#  ['rus', 'wti', 'rfs', 'vix'],
#  ['rus', 'ppi', 'rfs', 'vix'],
#  ['wti', 'ppi', 'rfs', 'vix'],
#  ['tby', 'ffr', 'fta', 'eps', 'div'],
#  ['tby', 'ffr', 'fta', 'eps', 'per'],
#  ['tby', 'ffr', 'fta', 'eps', 'une'],
#  ['tby', 'ffr', 'fta', 'eps', 'rus'],
#  ['tby', 'ffr', 'fta', 'eps', 'wti'],
#  ['tby', 'ffr', 'fta', 'eps', 'ppi'],
#  ['tby', 'ffr', 'fta', 'eps', 'rfs'],
#  ['tby', 'ffr', 'fta', 'eps', 'vix'],
#  ['tby', 'ffr', 'fta', 'div', 'per'],
#  ['tby', 'ffr', 'fta', 'div', 'une'],
#  ['tby', 'ffr', 'fta', 'div', 'rus'],
#  ['tby', 'ffr', 'fta', 'div', 'wti'],
#  ['tby', 'ffr', 'fta', 'div', 'ppi'],
#  ['tby', 'ffr', 'fta', 'div', 'rfs'],
#  ['tby', 'ffr', 'fta', 'div', 'vix'],
#  ['tby', 'ffr', 'fta', 'per', 'une'],
#  ['tby', 'ffr', 'fta', 'per', 'rus'],
#  ['tby', 'ffr', 'fta', 'per', 'wti'],
#  ['tby', 'ffr', 'fta', 'per', 'ppi'],
#  ['tby', 'ffr', 'fta', 'per', 'rfs'],
#  ['tby', 'ffr', 'fta', 'per', 'vix'],
#  ['tby', 'ffr', 'fta', 'une', 'rus'],
#  ['tby', 'ffr', 'fta', 'une', 'wti'],
#  ['tby', 'ffr', 'fta', 'une', 'ppi'],
#  ['tby', 'ffr', 'fta', 'une', 'rfs'],
#  ['tby', 'ffr', 'fta', 'une', 'vix'],
#  ['tby', 'ffr', 'fta', 'rus', 'wti'],
#  ['tby', 'ffr', 'fta', 'rus', 'ppi'],
#  ['tby', 'ffr', 'fta', 'rus', 'rfs'],
#  ['tby', 'ffr', 'fta', 'rus', 'vix'],
#  ['tby', 'ffr', 'fta', 'wti', 'ppi'],
#  ['tby', 'ffr', 'fta', 'wti', 'rfs'],
#  ['tby', 'ffr', 'fta', 'wti', 'vix'],
#  ['tby', 'ffr', 'fta', 'ppi', 'rfs'],
#  ['tby', 'ffr', 'fta', 'ppi', 'vix'],
#  ['tby', 'ffr', 'fta', 'rfs', 'vix'],
#  ['tby', 'ffr', 'eps', 'div', 'per'],
#  ['tby', 'ffr', 'eps', 'div', 'une'],
#  ['tby', 'ffr', 'eps', 'div', 'rus'],
#  ['tby', 'ffr', 'eps', 'div', 'wti'],
#  ['tby', 'ffr', 'eps', 'div', 'ppi'],
#  ['tby', 'ffr', 'eps', 'div', 'rfs'],
#  ['tby', 'ffr', 'eps', 'div', 'vix'],
#  ['tby', 'ffr', 'eps', 'per', 'une'],
#  ['tby', 'ffr', 'eps', 'per', 'rus'],
#  ['tby', 'ffr', 'eps', 'per', 'wti'],
#  ['tby', 'ffr', 'eps', 'per', 'ppi'],
#  ['tby', 'ffr', 'eps', 'per', 'rfs'],
#  ['tby', 'ffr', 'eps', 'per', 'vix'],
#  ['tby', 'ffr', 'eps', 'une', 'rus'],
#  ['tby', 'ffr', 'eps', 'une', 'wti'],
#  ['tby', 'ffr', 'eps', 'une', 'ppi'],
#  ['tby', 'ffr', 'eps', 'une', 'rfs'],
#  ['tby', 'ffr', 'eps', 'une', 'vix'],
#  ['tby', 'ffr', 'eps', 'rus', 'wti'],
#  ['tby', 'ffr', 'eps', 'rus', 'ppi'],
#  ['tby', 'ffr', 'eps', 'rus', 'rfs'],
#  ['tby', 'ffr', 'eps', 'rus', 'vix'],
#  ['tby', 'ffr', 'eps', 'wti', 'ppi'],
#  ['tby', 'ffr', 'eps', 'wti', 'rfs'],
#  ['tby', 'ffr', 'eps', 'wti', 'vix'],
#  ['tby', 'ffr', 'eps', 'ppi', 'rfs'],
#  ['tby', 'ffr', 'eps', 'ppi', 'vix'],
#  ['tby', 'ffr', 'eps', 'rfs', 'vix'],
#  ['tby', 'ffr', 'div', 'per', 'une'],
#  ['tby', 'ffr', 'div', 'per', 'rus'],
#  ['tby', 'ffr', 'div', 'per', 'wti'],
#  ['tby', 'ffr', 'div', 'per', 'ppi'],
#  ['tby', 'ffr', 'div', 'per', 'rfs'],
#  ['tby', 'ffr', 'div', 'per', 'vix'],
#  ['tby', 'ffr', 'div', 'une', 'rus'],
#  ['tby', 'ffr', 'div', 'une', 'wti'],
#  ['tby', 'ffr', 'div', 'une', 'ppi'],
#  ['tby', 'ffr', 'div', 'une', 'rfs'],
#  ['tby', 'ffr', 'div', 'une', 'vix'],
#  ['tby', 'ffr', 'div', 'rus', 'wti'],
#  ['tby', 'ffr', 'div', 'rus', 'ppi'],
#  ['tby', 'ffr', 'div', 'rus', 'rfs'],
#  ['tby', 'ffr', 'div', 'rus', 'vix'],
#  ['tby', 'ffr', 'div', 'wti', 'ppi'],
#  ['tby', 'ffr', 'div', 'wti', 'rfs'],
#  ['tby', 'ffr', 'div', 'wti', 'vix'],
#  ['tby', 'ffr', 'div', 'ppi', 'rfs'],
#  ['tby', 'ffr', 'div', 'ppi', 'vix'],
#  ['tby', 'ffr', 'div', 'rfs', 'vix'],
#  ['tby', 'ffr', 'per', 'une', 'rus'],
#  ['tby', 'ffr', 'per', 'une', 'wti'],
#  ['tby', 'ffr', 'per', 'une', 'ppi'],
#  ['tby', 'ffr', 'per', 'une', 'rfs'],
#  ['tby', 'ffr', 'per', 'une', 'vix'],
#  ['tby', 'ffr', 'per', 'rus', 'wti'],
#  ['tby', 'ffr', 'per', 'rus', 'ppi'],
#  ['tby', 'ffr', 'per', 'rus', 'rfs'],
#  ['tby', 'ffr', 'per', 'rus', 'vix'],
#  ['tby', 'ffr', 'per', 'wti', 'ppi'],
#  ['tby', 'ffr', 'per', 'wti', 'rfs'],
#  ['tby', 'ffr', 'per', 'wti', 'vix'],
#  ['tby', 'ffr', 'per', 'ppi', 'rfs'],
#  ['tby', 'ffr', 'per', 'ppi', 'vix'],
#  ['tby', 'ffr', 'per', 'rfs', 'vix'],
#  ['tby', 'ffr', 'une', 'rus', 'wti'],
#  ['tby', 'ffr', 'une', 'rus', 'ppi'],
#  ['tby', 'ffr', 'une', 'rus', 'rfs'],
#  ['tby', 'ffr', 'une', 'rus', 'vix'],
#  ['tby', 'ffr', 'une', 'wti', 'ppi'],
#  ['tby', 'ffr', 'une', 'wti', 'rfs'],
#  ['tby', 'ffr', 'une', 'wti', 'vix'],
#  ['tby', 'ffr', 'une', 'ppi', 'rfs'],
#  ['tby', 'ffr', 'une', 'ppi', 'vix'],
#  ['tby', 'ffr', 'une', 'rfs', 'vix'],
#  ['tby', 'ffr', 'rus', 'wti', 'ppi'],
#  ['tby', 'ffr', 'rus', 'wti', 'rfs'],
#  ['tby', 'ffr', 'rus', 'wti', 'vix'],
#  ['tby', 'ffr', 'rus', 'ppi', 'rfs'],
#  ['tby', 'ffr', 'rus', 'ppi', 'vix'],
#  ['tby', 'ffr', 'rus', 'rfs', 'vix'],
#  ['tby', 'ffr', 'wti', 'ppi', 'rfs'],
#  ['tby', 'ffr', 'wti', 'ppi', 'vix'],
#  ['tby', 'ffr', 'wti', 'rfs', 'vix'],
#  ['tby', 'ffr', 'ppi', 'rfs', 'vix'],
#  ['tby', 'fta', 'eps', 'div', 'per'],
#  ['tby', 'fta', 'eps', 'div', 'une'],
#  ['tby', 'fta', 'eps', 'div', 'rus'],
#  ['tby', 'fta', 'eps', 'div', 'wti'],
#  ['tby', 'fta', 'eps', 'div', 'ppi'],
#  ['tby', 'fta', 'eps', 'div', 'rfs'],
#  ['tby', 'fta', 'eps', 'div', 'vix'],
#  ['tby', 'fta', 'eps', 'per', 'une'],
#  ['tby', 'fta', 'eps', 'per', 'rus'],
#  ['tby', 'fta', 'eps', 'per', 'wti'],
#  ['tby', 'fta', 'eps', 'per', 'ppi'],
#  ['tby', 'fta', 'eps', 'per', 'rfs'],
#  ['tby', 'fta', 'eps', 'per', 'vix'],
#  ['tby', 'fta', 'eps', 'une', 'rus'],
#  ['tby', 'fta', 'eps', 'une', 'wti'],
#  ['tby', 'fta', 'eps', 'une', 'ppi'],
#  ['tby', 'fta', 'eps', 'une', 'rfs'],
#  ['tby', 'fta', 'eps', 'une', 'vix'],
#  ['tby', 'fta', 'eps', 'rus', 'wti'],
#  ['tby', 'fta', 'eps', 'rus', 'ppi'],
#  ['tby', 'fta', 'eps', 'rus', 'rfs'],
#  ['tby', 'fta', 'eps', 'rus', 'vix'],
#  ['tby', 'fta', 'eps', 'wti', 'ppi'],
#  ['tby', 'fta', 'eps', 'wti', 'rfs'],
#  ['tby', 'fta', 'eps', 'wti', 'vix'],
#  ['tby', 'fta', 'eps', 'ppi', 'rfs'],
#  ['tby', 'fta', 'eps', 'ppi', 'vix'],
#  ['tby', 'fta', 'eps', 'rfs', 'vix'],
#  ['tby', 'fta', 'div', 'per', 'une'],
#  ['tby', 'fta', 'div', 'per', 'rus'],
#  ['tby', 'fta', 'div', 'per', 'wti'],
#  ['tby', 'fta', 'div', 'per', 'ppi'],
#  ['tby', 'fta', 'div', 'per', 'rfs'],
#  ['tby', 'fta', 'div', 'per', 'vix'],
#  ['tby', 'fta', 'div', 'une', 'rus'],
#  ['tby', 'fta', 'div', 'une', 'wti'],
#  ['tby', 'fta', 'div', 'une', 'ppi'],
#  ['tby', 'fta', 'div', 'une', 'rfs'],
#  ['tby', 'fta', 'div', 'une', 'vix'],
#  ['tby', 'fta', 'div', 'rus', 'wti'],
#  ['tby', 'fta', 'div', 'rus', 'ppi'],
#  ['tby', 'fta', 'div', 'rus', 'rfs'],
#  ['tby', 'fta', 'div', 'rus', 'vix'],
#  ['tby', 'fta', 'div', 'wti', 'ppi'],
#  ['tby', 'fta', 'div', 'wti', 'rfs'],
#  ['tby', 'fta', 'div', 'wti', 'vix'],
#  ['tby', 'fta', 'div', 'ppi', 'rfs'],
#  ['tby', 'fta', 'div', 'ppi', 'vix'],
#  ['tby', 'fta', 'div', 'rfs', 'vix'],
#  ['tby', 'fta', 'per', 'une', 'rus'],
#  ['tby', 'fta', 'per', 'une', 'wti'],
#  ['tby', 'fta', 'per', 'une', 'ppi'],
#  ['tby', 'fta', 'per', 'une', 'rfs'],
#  ['tby', 'fta', 'per', 'une', 'vix'],
#  ['tby', 'fta', 'per', 'rus', 'wti'],
#  ['tby', 'fta', 'per', 'rus', 'ppi'],
#  ['tby', 'fta', 'per', 'rus', 'rfs'],
#  ['tby', 'fta', 'per', 'rus', 'vix'],
#  ['tby', 'fta', 'per', 'wti', 'ppi'],
#  ['tby', 'fta', 'per', 'wti', 'rfs'],
#  ['tby', 'fta', 'per', 'wti', 'vix'],
#  ['tby', 'fta', 'per', 'ppi', 'rfs'],
#  ['tby', 'fta', 'per', 'ppi', 'vix'],
#  ['tby', 'fta', 'per', 'rfs', 'vix'],
#  ['tby', 'fta', 'une', 'rus', 'wti'],
#  ['tby', 'fta', 'une', 'rus', 'ppi'],
#  ['tby', 'fta', 'une', 'rus', 'rfs'],
#  ['tby', 'fta', 'une', 'rus', 'vix'],
#  ['tby', 'fta', 'une', 'wti', 'ppi'],
#  ['tby', 'fta', 'une', 'wti', 'rfs'],
#  ['tby', 'fta', 'une', 'wti', 'vix'],
#  ['tby', 'fta', 'une', 'ppi', 'rfs'],
#  ['tby', 'fta', 'une', 'ppi', 'vix'],
#  ['tby', 'fta', 'une', 'rfs', 'vix'],
#  ['tby', 'fta', 'rus', 'wti', 'ppi'],
#  ['tby', 'fta', 'rus', 'wti', 'rfs'],
#  ['tby', 'fta', 'rus', 'wti', 'vix'],
#  ['tby', 'fta', 'rus', 'ppi', 'rfs'],
#  ['tby', 'fta', 'rus', 'ppi', 'vix'],
#  ['tby', 'fta', 'rus', 'rfs', 'vix'],
#  ['tby', 'fta', 'wti', 'ppi', 'rfs'],
#  ['tby', 'fta', 'wti', 'ppi', 'vix'],
#  ['tby', 'fta', 'wti', 'rfs', 'vix'],
#  ['tby', 'fta', 'ppi', 'rfs', 'vix'],
#  ['tby', 'eps', 'div', 'per', 'une'],
#  ['tby', 'eps', 'div', 'per', 'rus'],
#  ['tby', 'eps', 'div', 'per', 'wti'],
#  ...]

# %%
AIC_scores = []
parameters = []

for feats in power_feats:
    tmp_reg = OLS((df_train['diff']).copy(),df_train[feats].copy()).fit()
    AIC_scores.append(tmp_reg.aic)
    parameters.append(tmp_reg.params)

    
Min_AIC_index = AIC_scores.index(min(AIC_scores))
Min_AIC_feats = power_feats[Min_AIC_index]  
Min_AIC_params  = parameters[Min_AIC_index]
print(Min_AIC_feats)
print(Min_AIC_params)
# Out:
# ['tby', 'ffr', 'fta', 'eps', 'div', 'per', 'une', 'rus', 'wti', 'ppi', 'rfs', 'vix']
# tby   -139.802399
# ffr     59.572482
# fta     -0.000043
# eps     -7.039736
# div   -309.382346
# per     13.525559
# une     20.759948
# rus      0.795604
# wti      2.286543
# ppi      8.380622
# rfs     -0.002575
# vix     -6.008608
# dtype: float64

# %%
###After selecting the best features, we report the testing error, and make the plot 
AIC_df_test = df_test[Min_AIC_feats]
AIC_pred_test = AIC_df_test.dot(Min_AIC_params)+df_test.fbsp

AIC_df_train = df_train[Min_AIC_feats]
AIC_pred_train = AIC_df_train.dot(Min_AIC_params)+ df_train.fbsp

# %%
from sklearn.metrics import mean_squared_error as MSE

mse_train = MSE(df_train.y, AIC_pred_train) 
mse_test = MSE(df_test.y, AIC_pred_test)


#compare with fbprophet()

fb_mse_train = MSE(df_train.y, df_train.fbsp) 
fb_mse_test = MSE(df_test.y, df_test.fbsp)


print(mse_train,fb_mse_train)

print(mse_test,fb_mse_test)
# Out:
# 11150.956256956993 26703.722042015484
# 14835.844341962336 15912.681373065194

# %%
plt.figure(figsize=(13,6))
plt.plot(df_test.y,label="true price")
plt.plot(df_test.fbsp,label="fbprophet prediction")
plt.plot(AIC_pred_test,label="Prediction by Best_AIC")
plt.legend(fontsize = 14)
plt.show()
